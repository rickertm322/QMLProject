# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import numpy as np
import argparse
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#images -> feature values
#number of feature values is n -> need n qubits
#for now will generate feature values randomly, using n = 4. 
f = np.random.rand(1,4)
fmax = f.max()

def theta(i):
    return (np.pi/4)*(f[0,i]/fmax)
#in algorithm 1 part of the paper, this formula is described to calculate angle of rotation for RY gates

m, n = f.shape[0], f.shape[1]
#defining n as length of features- for easier transition to actual feature value dataset
f
# Out:
# array([[0.63941644, 0.81769979, 0.33646643, 0.5976553 ]])

# %%
# Create a new circuit with two qubits
qc = QuantumCircuit(n)

#in qiskit, qubits are automatically initialized to 0
for i in range(n):
    qc.h(i) #add hadamard gate to all lines
    #qc.h(qubit its on)
    qc.ry(theta(i),i) #add ry gate with theta func
    #qc.h(angle, qubit its on)
    if i<n-1:
        qc.cx(i,i+1) #controlled not gate (CNOT) 
        #qc.cx(from, to)
    qc.x(i)
    #qc.x(qubit its on)
    if i<n-1: 
        qc.cry(theta(i),i,i+1)
        #qc.cry(angle, from, to)
    qc.x(i)

output = qc.measure_all()
qc.draw('mpl')
#draws the circuit

# %%
simulator = AerSimulator()

job = simulator.run(qc, shots=1000)

result = job.result()

counts = result.get_counts(qc)
print(f"Measurement counts: {counts}")

from qiskit.visualization import plot_histogram
plot_histogram(counts)
# Out:
# Measurement counts: {'0001': 130, '1001': 178, '0101': 230, '0011': 75, '1101': 75, '0100': 30, '1011': 107, '0000': 14, '1000': 27, '0110': 7, '1111': 21, '1100': 11, '0111': 55, '1010': 23, '0010': 14, '1110': 3}

# %%
import pandas as pd

df = pd.DataFrame(columns = counts.keys())

# %%
row = pd.DataFrame(columns = counts.keys(), )
df = pd.concat([df, row])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 row = pd.DataFrame(counts)
#       2 df = pd.concat([df, row])
#
# File \\?\C:\Users\ricke\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
df
# Out:
#   0001 1001 0101 0011 1101 0100 1011 0000 1000 0110  ...      6     7     8  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  107.0  14.0  27.0
#
#      9    10    11    12    13    14   15
# 0  7.0  21.0  11.0  55.0  23.0  14.0  3.0
#
# [1 rows x 32 columns]

# %%
qc_template = QuantumCircuit(n_qubits)

par_inputs = ParameterVector("input", n_qubits)
par_weights = ParameterVector(r"$\theta$", n_parameters)

for i in range(n_qubits):
    qc_template.rx(par_inputs[i] * par_weights[i], i)

for i in range(n_layers):
    for j in range(n_qubits):
        qc_template.ry(par_weights[n_par_per_layer*i + n_rots*j + 0 + n_qubits], j)
        qc_template.rz(par_weights[n_par_per_layer*i + n_rots*j + 1 + n_qubits], j)
        # qc.ry(par_weights[n_par_per_layer*i + n_rots*j + 2], j)
    for j in range(n_qubits-1, 0, -1):
        qc_template.cx(j-1, j)

if final_rotation_layer:
    for j in range(n_qubits):
        qc_template.ry(par_weights[n_par_per_layer*n_layers + n_rots*j + 0 + n_qubits], j)
        qc_template.rz(par_weights[n_par_per_layer*n_layers + n_rots*j + 1 + n_qubits], j)


# one can define an observable and use that as the output
# obs = SparsePauliOp("IZII")

## Or we can just measure the raw qubit output
## Here, let's use the output of the second qubit to indicate the predicted class
qc_template.measure_all()

## compile the circuit
## not necessary here, but it should reduce the cost a little
## for running on IBM qpu, this is needed
isa_circ = pm.run(qc_template)
# isa_obs  = obs.apply_layout(isa_circ.layout)

qc_template.draw()
